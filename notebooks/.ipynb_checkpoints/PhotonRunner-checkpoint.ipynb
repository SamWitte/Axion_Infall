# %%
using Plots
using LinearAlgebra
using NLsolve
using Statistics
using NPZ
using SpecialFunctions

# %%
include("../src/photon_raytrace.jl")
# Out:
# WARNING: replacing module RayTracer.
# ConvL_weights (generic function with 1 method)

# %%
Mass_a = 1e-6;
Ax_g = 1e-12;
Mass_NS=1;
θm = 0.2;
ωPul = 1.0;
B0 = 1e14;
rNS = 10;
NS_vel = [0 0 200.0] ./ 2.998e5;
ln_t_start = 1e-20
ln_t_end = 1
t_list = [0]
main_runner(Mass_a, Ax_g, θm, ωPul, B0, rNS, Mass_NS, t_list; ode_err=1e-5, CLen_Scale=true, v_NS=NS_vel)
# Out:
# [1.0127369663612495e-6; 1.0127203885103468e-6; 1.0127427633135477e-6]	[1.0127369663612508e-6; 1.0127203885103478e-6; 1.0127427633135613e-6]	[5.5894496522839634e-11; 5.548222511782014e-11; 6.532361697642756e-10; 6.48430104022671e-10; 1.2286393327736939e-9; 1.2196594869057842e-9; 1.7615709854794497e-9; 1.7488282136369175e-9; 2.2309144247905594e-9; 2.2149914043918605e-9; 2.6153065060729692e-9; 2.5969311738798233e-9; 2.894047926822326e-9; 2.874060816297761e-9; 3.048557466423482e-9; 3.027874410471065e-9; 3.0642390653653363e-9; 3.0438107133667993e-9; 2.9324902320476654e-9; 2.913259681780816e-9; 2.6525423918513482e-9; 2.635402345187828e-9; 2.2327730232558827e-9; 2.2185240145744095e-9; 1.6911933612267644e-9; 1.6805049556916477e-9; 1.0549096989894073e-9; 1.0482868495376963e-9; 3.5850723298928913e-10; 3.562640749700884e-10; -3.5850721932553064e-10; -3.562640613919068e-10; -1.0549096861061214e-9; -1.048286836735875e-9; -1.691193349840101e-9; -1.6805049443783847e-9; -2.2327730139613803e-9; -2.21
# ...

# %%
1.0127472677776623e-6 .- 1.0127472677776623e-6
# Out:
# 0.0
